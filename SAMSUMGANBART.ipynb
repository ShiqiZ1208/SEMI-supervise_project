# %% [markdown]
# <a href="https://colab.research.google.com/github/ShiqiZ1208/LecSumGANBart/blob/main/SAMSUMGANBART.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # access drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %% [markdown]
# # git clone

# %%
# !ls
# Out:
# drive  sample_data

# %%
# !git clone https://github.com/ShiqiZ1208/LecSumGANBart.git
# Out:
# Cloning into 'LecSumGANBart'...
# remote: Enumerating objects: 177, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 177 (delta 9), reused 1 (delta 1), pack-reused 160 (from 3)
# Receiving objects: 100% (177/177), 2.46 MiB | 22.10 MiB/s, done.
# Resolving deltas: 100% (84/84), done.

# %% [markdown]
# # workspace

# %%
# %cd LecSumGANBart
# Out:
# /content/drive/MyDrive/LecSumGANBart

# %%
# !pip install -r requirement.txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 5.8 MB/s eta 0:00:00
# ...
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=0e414c59f11c5ea587b701375d74d8edfdeaa13860296df33a89a8d5f7c529a0
#   Stored in directory: /root/.cache/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
# Successfully built rouge_score
# ...

# %%
# !python main.py -o train -b 8 -e 1 -save true -l false -mode GAN
# Out:
# 2025-11-19 05:38:46.894487: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763530726.914941  191751 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763530726.921057  191751 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763530726.937418  191751 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python main.py -o evaluate -g '/content/drive/MyDrive/LecSumGANBart/SaveModel/lora_bartGAN_1_8' -i '/content/drive/MyDrive/LecSumGANBart/result/test result.txt'
# Out:
# 2025-11-19 10:51:21.816832: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763549481.836072    1566 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763549481.842036    1566 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763549481.857052    1566 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
import torch
from transformers import BartTokenizer, RobertaTokenizer

# Load tokenizers
bart_tokenizer = BartTokenizer.from_pretrained("facebook/bart-base")
roberta_tokenizer = RobertaTokenizer.from_pretrained("roberta-base")

# Example text
text = "Hello world."

# 1️⃣ Tokenize with BART
bart_ids = bart_tokenizer.encode(text, add_special_tokens=True)
print("BART IDs:", bart_ids)

# 2️⃣ Tokenize with RoBERTa
roberta_ids = roberta_tokenizer.encode(text, add_special_tokens=True)
print("RoBERTa IDs:", roberta_ids)

# 3️⃣ Compare
for i, (b_id, r_id) in enumerate(zip(bart_ids, roberta_ids)):
    print(f"Token {i}: BART ID={b_id}, RoBERTa ID={r_id}, Match={b_id==r_id}")

# 4️⃣ Decode to confirm text
print("\nDecoded BART text:", bart_tokenizer.decode(bart_ids))
print("Decoded RoBERTa text:", roberta_tokenizer.decode(roberta_ids))
# Out:
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# BART IDs: [0, 31414, 232, 4, 2]
# RoBERTa IDs: [0, 31414, 232, 4, 2]
# Token 0: BART ID=0, RoBERTa ID=0, Match=True
# Token 1: BART ID=31414, RoBERTa ID=31414, Match=True
# Token 2: BART ID=232, RoBERTa ID=232, Match=True
# Token 3: BART ID=4, RoBERTa ID=4, Match=True
# Token 4: BART ID=2, RoBERTa ID=2, Match=True
#
# Decoded BART text: <s>Hello world.</s>
# Decoded RoBERTa text: <s>Hello world.</s>
